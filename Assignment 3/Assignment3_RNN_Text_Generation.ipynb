# %% [markdown]
# # Assignment 3: Character-Level RNN for Text Generation

# %% [markdown]
# LSTM/GRU based text generation notebook using Shakespeare corpus.

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# ## Load and Analyze Text Corpus

# %%
with open('shakespeare.txt','r',encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
print('Total Characters:', len(text))
print('Vocabulary Size:', len(chars))

# %% [markdown]
# ## Character Mappings

# %%
char2idx = {c:i for i,c in enumerate(chars)}
idx2char = {i:c for c,i in char2idx.items()}

# %% [markdown]
# ## Sequence Generation

# %%
seq_length = 100
stride = 3

# %% [markdown]
# ## LSTM Model

# %%
class CharLSTM(nn.Module):
    def __init__(self,vocab_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size,128)
        self.lstm = nn.LSTM(128,256,num_layers=2,batch_first=True,dropout=0.3)
        self.fc = nn.Linear(256,vocab_size)

    def forward(self,x):
        x = self.embedding(x)
        out,_ = self.lstm(x)
        return self.fc(out[:,-1,:])

# %% [markdown]
# ## Training Loop

# %%
model = CharLSTM(len(chars))
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## Text Generation with Temperature Sampling

# %%
def generate_text(seed_text, length=500, temperature=1.0):
    return 'Generated Text Placeholder'

# %% [markdown]
# ## Experiments: LSTM vs GRU, Temperature, Sequence Length
