# %% [markdown]
# # Assignment 6: Deep Learning Capstone Project

# %% [markdown]
# Capstone notebook template. This version uses **Track A: Sentiment Analysis with Advanced NLP** and includes sections for data preparation, multiple models, evaluation, deployment, and reporting.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ## Phase 1 - Data Preparation

# %%
# Load IMDB / Sentiment140 / Amazon Reviews dataset
# Text cleaning, tokenization, stopword removal
# Vocabulary creation (top 10000 words)
# Sequence padding

# %% [markdown]
# ## Word Embeddings

# %%
# Train Word2Vec
# Load GloVe embeddings
# Compare both approaches

# %% [markdown]
# ## Model 1 - Bidirectional LSTM

# %%
class BiLSTM(nn.Module):
    pass

# %% [markdown]
# ## Model 2 - GRU with Attention

# %%
class GRUAttention(nn.Module):
    pass

# %% [markdown]
# ## Model 3 - CNN for Text

# %%
class TextCNN(nn.Module):
    pass

# %% [markdown]
# ## Training and Validation

# %%
# Train/validation/test split
# LR scheduling
# Early stopping
# Save best model

# %% [markdown]
# ## Evaluation

# %%
# Accuracy, Precision, Recall, F1
# Confusion Matrix
# Error Analysis

# %% [markdown]
# ## Ensemble Learning

# %%
# Combine top 3 models

# %% [markdown]
# ## Streamlit / Gradio Demo

# %%
# Real-time sentiment prediction interface

# %% [markdown]
# ## Flask/FastAPI Deployment

# %%
# REST API template

# %% [markdown]
# ## Report and Results
