# %% [markdown]
# # Assignment 2: CNN for CIFAR-10 Image Classification

# %% [markdown]
# Notebook template for CIFAR-10 CNN assignment.

# %%
import torch
import torchvision
import torch.nn as nn

# %%
class BaselineCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3,32,3,padding=1)
        self.conv2 = nn.Conv2d(32,64,3,padding=1)
